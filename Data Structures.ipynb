# %% [markdown]
# Lists -
# heterogenous, mutable, ordered, duplicates are allowed              #properties

# %%
a=[1,3,"apple",4.5,True,4+5j]
print(a)
print(a[0])
print(a[3])
print(a[0:3])
a[4]="orange"
print(a)
print(a[:])
a[4]="thorn"
print(a)
print(a[:])
# Out:
# [1, 3, 'apple', 4.5, True, (4+5j)]
# 1
# 4.5
# [1, 3, 'apple']
# [1, 3, 'apple', 4.5, 'orange', (4+5j)]
# [1, 3, 'apple', 4.5, 'orange', (4+5j)]
# [1, 3, 'apple', 4.5, 'thorn', (4+5j)]
# [1, 3, 'apple', 4.5, 'thorn', (4+5j)]
