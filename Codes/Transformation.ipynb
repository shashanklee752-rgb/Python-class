# %% [markdown]
# #data transformation
# .map() replaces values using a dictionary mapping
#
# map in pandas is used to transform or substitute values in a single column(series)
#
# using mapping rules
# commonly used in data cleaning or feature engineering
#
# syntax: - series.map(mapping)
#
# here mapping can be another:
#
# dictionary
# a function
# another series

# %%
import pandas as pd
data={"City":
    ["Bangalore","Delhi","Mumbai"]
    }
df=pd.DataFrame(data)
df
# Out:
#         City
# 0  Bangalore
# 1      Delhi
# 2     Mumbai

# %%
#convert city names to regions
region_map={"Bangalore":"South",
            "Delhi":"North",
            "Mumbai":"West"
            }

df["Region"]=df["City"].map(region_map)
df
# Out:
#         City Region
# 0  Bangalore  South
# 1      Delhi  North
# 2     Mumbai   West

# %%
#mapping using a function
#.map() can apply a function to each value

df["City_length"]=df["City"].map(len)
df
# Out:
#         City Region  City_length
# 0  Bangalore  South            9
# 1      Delhi  North            5
# 2     Mumbai   West            6

# %%
#mapping through a series
city_series=pd.Series({"Bangalore":"South",
                       "Delhi":"North",
                       "Mumbai":"West"})
df["Region"]=df["City"].map(city_series)
df
# Out:
#         City Region  City_length
# 0  Bangalore  South            9
# 1      Delhi  North            5
# 2     Mumbai   West            6

# %%
#mapping with missing values
#when there are missing values its filled with NaN
region_map={"Bangalore":"South",
            "Delhi":"North"
            }
df["Region"]=df["City"].map(region_map)
df
# Out:
#         City Region  City_length
# 0  Bangalore  South            9
# 1      Delhi  North            5
# 2     Mumbai    NaN            6

# %%
#filling missing values

df["Region"]=df["City"].map(region_map).fillna("other")
df
# Out:
#         City Region  City_length
# 0  Bangalore  South            9
# 1      Delhi  North            5
# 2     Mumbai  other            6

# %%
import pandas as pd
import numpy as np
data={"customer":["Asha","Bala","Chitra"],
      "Sales":[50000,30000,15000]}
df=pd.DataFrame(data)

# %%
#applying custom functions
#.apply() lets us run custom logic on rows or columns

#example -classify sales performance

def sales_category(x):
    if x>40000:
        return "HIGH"
    elif x>25000:
        return "MEDIUM"
    else:
        return "LOW"
    
    #apply function

df["sales_category"]=df["Sales"].apply(sales_category)
df
# Out:
#   customer  Sales sales_category
# 0     Asha  50000           HIGH
# 1     Bala  30000         MEDIUM
# 2   Chitra  15000            LOW

# %%
#create a column called double_sales using lambda with apply function
df["Double_sales"]=df["Sales"].apply(lambda x:x*2)
df
# Out:
#   customer  Sales sales_category  Double_sales
# 0     Asha  50000           HIGH        100000
# 1     Bala  30000         MEDIUM         60000
# 2   Chitra  15000            LOW         30000

# %%
#apply on entire dataframe
df.apply(lambda x:x*2)
# Out:
#        customer   Sales sales_category  Double_sales
# 0      AshaAsha  100000       HIGHHIGH        200000
# 1      BalaBala   60000   MEDIUMMEDIUM        120000
# 2  ChitraChitra   30000         LOWLOW         60000

# %%
#apply with axis
#axis=0    operates on columns
#axis=1    operates on rows

df.apply(np.sum,axis=0)
#calculates sum column-wise
# Out:
# customer    AshaBalaChitra
# Sales                95000
# dtype: object

# %%
data={
    "A":[10,20,30,40],
    "B":[1,2,3,4]
}
df=pd.DataFrame(data)
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4

# %%
df.apply(lambda row:row["A"]+row["B"],axis=1)

#row wise operation
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
data={"Revenue":[50000,30000],
       "Cost":[20000,15000]
       }
df=pd.DataFrame(data)
df
# Out:
#    Revenue   Cost
# 0    50000  20000
# 1    30000  15000

# %%
df["Profit"]=df.apply(lambda row:row["Revenue"]-row["Cost"],axis=1)
df
# Out:
#    Revenue   Cost  Profit
# 0    50000  20000   30000
# 1    30000  15000   15000

# %%
import pandas as pd
import numpy as np
data={"customer":["Asha","Bala","Chitra"],
      "Sales":["50000","30000","15000"]}
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   customer  3 non-null      str
#  1   Sales     3 non-null      str
# dtypes: str(2)
# memory usage: 180.0 bytes

# %%
#astype - type conversion
#example- sometimes numbers might be sorted as strings

df["Sales"]=df["Sales"].astype(int)
df.info()

#converting sales values datatype to numeric
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   customer  3 non-null      str
#  1   Sales     3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %%
data={"customer":["Asha","Bala","Chitra"],
      "Sales":["50000","30000","missing"]}
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   customer  3 non-null      str
#  1   Sales     3 non-null      str
# dtypes: str(2)
# memory usage: 180.0 bytes

# %%
#to_numeric is used for type conversion
pd.to_numeric(df["Sales"],errors="coerce")
# Out:
# 0    50000.0
# 1    30000.0
# 2        NaN
# Name: Sales, dtype: float64

# %% [markdown]
# .apply is a last option or last resort because .apply runs python loops internally
#
# this is not useful when there are millions of rows
# in this case we would prefer vectorization(numpy vectorization)
# numpy vectorization is faster
